# %%
client_id='b8kc6gexsv'
client_secret='WmuJYC9tgkTfJLUzfvDUEJm4Gq1k3KLvf6N6zuix'

# %%
# !pip install folium

# %%
import folium
#import pandas as pd
import urllib.request
import datetime
import time
import json
import os
import sys
import webbrowser

# %%
def get_request_url(url):
    
    req = urllib.request.Request(url)
    req.add_header("X-NCP-APIGW-API-KEY-ID", client_id)
    req.add_header("X-NCP-APIGW-API-KEY", client_secret)
    try: 
        response = urllib.request.urlopen(req)
        if response.getcode() == 200:
            print ("[%s] Url Request Success" % datetime.datetime.now())
            return response.read().decode('utf-8')
    except Exception as e:
        print(e)
        print("[%s] Error for URL : %s" % (datetime.datetime.now(), url))
        return None

# %%
#[CODE 2]
def getGeoData(address):
    
    base = "https://naveropenapi.apigw.ntruss.com/map-geocode/v2/geocode"
    
    try:
        parameters = "?query=%s" % urllib.parse.quote(address)
    except:
        return None
    
    url = base + parameters
    
    retData = get_request_url(url)
    if retData == None:
        return None

    jsonAddress = json.loads(retData)

    if 'addresses' in jsonAddress.keys():
        if jsonAddress['addresses'] != []:
            latitude = jsonAddress['addresses'][0]['y']
            longitude = jsonAddress['addresses'][0]['x']
        else:
            return None
    else:
        return None
    
    return [latitude, longitude]

# %%
seoul_sb = folium.Map(location=[37.5642135,127.0016985], zoom_start=11)
seoul_sb
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
#[CODE 4]
import pandas as pd
filename = '서울_스벅.csv'
df = pd.read_csv(filename, encoding='utf-8-sig')
geoData = []
    
for index, row in df.iterrows():
    geoData = getGeoData(row['store_address'])

    if geoData != None:
        folium.Marker(geoData, popup=row['store_name'], icon=folium.Icon(color='red')).add_to(seoul_sb)
# Out:
# [2021-12-21 23:00:32.985150] Url Request Success
# [2021-12-21 23:00:33.140657] Url Request Success
# [2021-12-21 23:00:33.297614] Url Request Success
# [2021-12-21 23:00:33.470672] Url Request Success
# [2021-12-21 23:00:33.620599] Url Request Success
# [2021-12-21 23:00:33.786772] Url Request Success
# [2021-12-21 23:00:33.944643] Url Request Success
# [2021-12-21 23:00:34.096040] Url Request Success
# [2021-12-21 23:00:34.266634] Url Request Success
# [2021-12-21 23:00:34.425837] Url Request Success
# [2021-12-21 23:00:34.570031] Url Request Success
# [2021-12-21 23:00:34.731908] Url Request Success
# [2021-12-21 23:00:34.859019] Url Request Success
# [2021-12-21 23:00:34.995045] Url Request Success
# [2021-12-21 23:00:35.158735] Url Request Success
# [2021-12-21 23:00:35.365207] Url Request Success
# [2021-12-21 23:00:35.506789] Url Request Success
# [2021-12-21 23:00:35.648074] Url Request Success
# [2021-12-21 23:00:35.811286] Url Request Success
# ...

# %%
seoul_sb
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
ulsan_sb = folium.Map(location=[35.5437411,129.2540956], zoom_start=12)
ulsan_sb
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
#[CODE 4]
import pandas as pd
filename = '울산_스벅.csv'
df = pd.read_csv(filename, encoding='utf-8-sig')
geoData = []
    
#for index, row in df.iterrows():
#    geoData = getGeoData(row['store_address'])

#    if geoData != None:
        #folium.CircleMarker(geoData, popup=row['store_name'], radius=100, color='#3186cc', fill_color='#3186cc',icon=folium.Icon(color='red')).add_to(ulsan_sb)
#        folium.Marker(geoData, popup=row['store_name'], icon=folium.Icon(color='red')).add_to(ulsan_sb)

# %%
import pandas as pd
filename = '울산_이디야.csv'
df = pd.read_csv(filename, encoding='utf-8-sig')
geoData = []
    
for index, row in df.iterrows():
    geoData = getGeoData(row['store_address'])

    if geoData != None:
        folium.Marker(geoData, popup=row['store_name'], icon=folium.Icon(color='blue')).add_to(ulsan_sb)
# Out:
# [2021-12-21 23:02:12.303753] Url Request Success
# [2021-12-21 23:02:12.533130] Url Request Success
# [2021-12-21 23:02:12.684727] Url Request Success
# [2021-12-21 23:02:12.836460] Url Request Success
# [2021-12-21 23:02:13.052350] Url Request Success
# [2021-12-21 23:02:13.214955] Url Request Success
# [2021-12-21 23:02:13.359195] Url Request Success
# [2021-12-21 23:02:13.517928] Url Request Success
# [2021-12-21 23:02:13.693031] Url Request Success
# [2021-12-21 23:02:13.826860] Url Request Success
# [2021-12-21 23:02:14.003793] Url Request Success
# [2021-12-21 23:02:14.185125] Url Request Success
# [2021-12-21 23:02:14.338295] Url Request Success
# [2021-12-21 23:02:14.526363] Url Request Success
# [2021-12-21 23:02:14.697111] Url Request Success
# [2021-12-21 23:02:14.873571] Url Request Success
# [2021-12-21 23:02:15.035035] Url Request Success
# [2021-12-21 23:02:15.207081] Url Request Success
# [2021-12-21 23:02:15.382883] Url Request Success
# ...

# %%
ulsan_sb
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
import json
geo_path = '02. skorea_municipalities_geo_simple.json'
geo_str = json.load(open(geo_path, encoding='utf-8' ) )

# %%
map = folium.Map(location=[37.5502, 126.982], zoom_start=11)

# %%
data=pd.read_csv('clustering.csv', encoding='utf-8-sig')
data=data.groupby('행정구').mean()
data.head()
# Out:
#           임대료     매출액      건수   생존율      인구 수   여성 비율  소득 분위    음식점 수  직장 인구  \
# 행정구
# 강남구  143087.5  1621.5  2040.0  75.6  535827.0  52.150    9.0  13799.0  293.0
# 강동구  106317.5  1197.5  1720.5  80.0  466664.0  50.875    7.0   5607.0   29.0
# 강북구   88253.5  1090.5  1542.5  82.2  303939.5  51.320    6.5   4092.5   12.0
# 강서구  110054.0  1434.5  2336.5  78.6  579422.5  51.830    7.0   7064.5   35.0
# 관악구  109576.5  1212.0  1973.5  78.7  495518.0  49.855    6.0   6140.5   25.0
#
#      생존율_3  생존율_5
# 행정구
# 강남구  48.15  29.85
# 강동구  49.35  33.55
# 강북구  47.55  31.10
# 강서구  47.30  28.40
# 관악구  44.25  22.85

# %%
map.choropleth(geo_data = geo_str,
               data = data['매출액'],
               columns = [data.index, data['매출액']],
               fill_color = 'PuRd', #puRd, YlGnBu
               key_on = 'feature.id')
# Out:
# C:\Users\dleot\anaconda3\lib\site-packages\folium\folium.py:409: FutureWarning: The choropleth  method has been deprecated. Instead use the new Choropleth class, which has the same arguments. See the example notebook 'GeoJSON_and_choropleth' for how to do this.
#   warnings.warn(

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
map = folium.Map(location=[37.5502, 126.982], zoom_start=11)
map.choropleth(geo_data = geo_str,
               data = data['임대료'],
               columns = [data.index, data['임대료']],
               fill_color = 'PuRd', #puRd, YlGnBu
               key_on = 'feature.id')
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
map = folium.Map(location=[37.5502, 126.982], zoom_start=11)
map.choropleth(geo_data = geo_str,
               data = data['생존율_5'],
               columns = [data.index, data['생존율_5']],
               fill_color = 'PuRd', #PuBuGn, 
               key_on = 'feature.id')
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
import csv
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()  # for plot styling
import numpy as np
import platform

from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    path = "c:/Windows/Fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system... sorry~~~~') 
plt.figure()
data['생존율_5'].sort_values().plot(kind='barh', grid=True, figsize=(10, 10))
plt.title('생존율 순위')
plt.show()

# %%
data=pd.read_csv('clustering.csv', encoding='utf-8-sig')
data=data.groupby('행정구').mean()
data.head()
# Out:
#           임대료     매출액      건수   생존율      인구 수   여성 비율  소득 분위    음식점 수  직장 인구  \
# 행정구
# 강남구  143087.5  1621.5  2040.0  75.6  535827.0  52.150    9.0  13799.0  293.0
# 강동구  106317.5  1197.5  1720.5  80.0  466664.0  50.875    7.0   5607.0   29.0
# 강북구   88253.5  1090.5  1542.5  82.2  303939.5  51.320    6.5   4092.5   12.0
# 강서구  110054.0  1434.5  2336.5  78.6  579422.5  51.830    7.0   7064.5   35.0
# 관악구  109576.5  1212.0  1973.5  78.7  495518.0  49.855    6.0   6140.5   25.0
#
#      생존율_3  생존율_5
# 행정구
# 강남구  48.15  29.85
# 강동구  49.35  33.55
# 강북구  47.55  31.10
# 강서구  47.30  28.40
# 관악구  44.25  22.85

# %%
data.index
# Out:
# Index(['강남구', '강동구', '강북구', '강서구', '관악구', '광진구', '구로구', '금천구', '노원구', '도봉구',
#        '동대문구', '동작구', '마포구', '서대문구', '서초구', '성동구', '성북구', '송파구', '양천구', '영등포구',
#        '용산구', '은평구', '종로구', '중구', '중랑구'],
#       dtype='object', name='행정구')

# %%
data['bin']=[0]*23+[1]+[0]

# %%
map = folium.Map(location=[37.5502, 126.982], zoom_start=11)
map.choropleth(geo_data = geo_str,
               data = data['bin'],
               columns = [data.index, data['bin']],
               fill_color = 'Reds', #PuBuGn, 
               key_on = 'feature.id')
map
# Out:
# C:\Users\dleot\anaconda3\lib\site-packages\folium\folium.py:409: FutureWarning: The choropleth  method has been deprecated. Instead use the new Choropleth class, which has the same arguments. See the example notebook 'GeoJSON_and_choropleth' for how to do this.
#   warnings.warn(
# ...

# %%
data.index
# Out:
# Index(['강남구', '강동구', '강북구', '강서구', '관악구', '광진구', '구로구', '금천구', '노원구', '도봉구',
#        '동대문구', '동작구', '마포구', '서대문구', '서초구', '성동구', '성북구', '송파구', '양천구', '영등포구',
#        '용산구', '은평구', '종로구', '중구', '중랑구'],
#       dtype='object', name='행정구')

# %%
data=pd.read_csv('clustering.csv', encoding='utf-8-sig')
data=data.groupby('행정구').mean()
data.head()
# Out:
#           임대료     매출액      건수   생존율      인구 수   여성 비율  소득 분위    음식점 수  직장 인구  \
# 행정구
# 강남구  143087.5  1621.5  2040.0  75.6  535827.0  52.150    9.0  13799.0  293.0
# 강동구  106317.5  1197.5  1720.5  80.0  466664.0  50.875    7.0   5607.0   29.0
# 강북구   88253.5  1090.5  1542.5  82.2  303939.5  51.320    6.5   4092.5   12.0
# 강서구  110054.0  1434.5  2336.5  78.6  579422.5  51.830    7.0   7064.5   35.0
# 관악구  109576.5  1212.0  1973.5  78.7  495518.0  49.855    6.0   6140.5   25.0
#
#      생존율_3  생존율_5
# 행정구
# 강남구  48.15  29.85
# 강동구  49.35  33.55
# 강북구  47.55  31.10
# 강서구  47.30  28.40
# 관악구  44.25  22.85

# %%
# '강남구', '성동구', '서초구', '강서구', '용산구', '종로구', '구로구', '영등포구', '금천구', '송파구'
data['bin']=[0]*25
data.loc[['강남구', '성동구', '서초구', '강서구', '용산구', '종로구', '구로구', '영등포구', '금천구', '송파구'], ['bin']]=1

# %%
map = folium.Map(location=[37.5502, 126.982], zoom_start=11)
map.choropleth(geo_data = geo_str,
               data = data['bin'],
               columns = [data.index, data['bin']],
               fill_color = 'Blues', #PuBuGn, 
               key_on = 'feature.id')
map
# Out:
# C:\Users\dleot\anaconda3\lib\site-packages\folium\folium.py:409: FutureWarning: The choropleth  method has been deprecated. Instead use the new Choropleth class, which has the same arguments. See the example notebook 'GeoJSON_and_choropleth' for how to do this.
#   warnings.warn(
# ...

# %%
data=pd.read_csv('clustering.csv', encoding='utf-8-sig')
data=data.groupby('행정구').mean()
data.head()
# Out:
#           임대료     매출액      건수   생존율      인구 수   여성 비율  소득 분위    음식점 수  직장 인구  \
# 행정구
# 강남구  143087.5  1621.5  2040.0  75.6  535827.0  52.150    9.0  13799.0  293.0
# 강동구  106317.5  1197.5  1720.5  80.0  466664.0  50.875    7.0   5607.0   29.0
# 강북구   88253.5  1090.5  1542.5  82.2  303939.5  51.320    6.5   4092.5   12.0
# 강서구  110054.0  1434.5  2336.5  78.6  579422.5  51.830    7.0   7064.5   35.0
# 관악구  109576.5  1212.0  1973.5  78.7  495518.0  49.855    6.0   6140.5   25.0
#
#      생존율_3  생존율_5
# 행정구
# 강남구  48.15  29.85
# 강동구  49.35  33.55
# 강북구  47.55  31.10
# 강서구  47.30  28.40
# 관악구  44.25  22.85

# %%
data['bin']=[0]*25
data.loc[['중랑구', '노원구', '강동구', '관악구', '마포구', '양천구', '성북구', '동작구', '도봉구', '강북구', '서대문구', '동대문구', '광진구', '은평구'], ['bin']]=1

# %%
map = folium.Map(location=[37.5502, 126.982], zoom_start=11)
map.choropleth(geo_data = geo_str,
               data = data['bin'],
               columns = [data.index, data['bin']],
               fill_color = 'Greens', #PuBuGn, 
               key_on = 'feature.id')
map
# Out:
# C:\Users\dleot\anaconda3\lib\site-packages\folium\folium.py:409: FutureWarning: The choropleth  method has been deprecated. Instead use the new Choropleth class, which has the same arguments. See the example notebook 'GeoJSON_and_choropleth' for how to do this.
#   warnings.warn(
# ...
